# %% [markdown]
# ### spectral µTransfer 350m

# %%
import torch

# %%
NAME_TO_FAN_MAPPING = {
    # NOTE: the original
    # "token_embedding.weight": [49152, 1024],
    # "token_embedding.bias": [49152, 1],
    
    "token_embedding.weight": [1, 1024],
    "token_embedding.bias": [1, 1],
    
    # NOTE:
    "qkv_proj.weight": [1024, 2048],
    "qkv_proj.bias": [1024, 1],
    "o_proj.weight": [1024, 1024],
    "o_proj.bias": [1024, 1],
    "gate_up_proj.weight": [1024, 8192],
    "gate_up_proj.bias": [1024, 1],
    "down_proj.weight": [4096, 1024],
    "down_proj.bias": [4096, 1],
    "lm_head.pp_block.weight": [1024, 49152],
    # "token_embedding.bias": [1024, 1],
}

# %%
def spectral_lr(fan_in, fan_out):
    """Spectral parameterization from the [paper](https://arxiv.org/abs/2310.17813)."""
    return (fan_out / fan_in) / 64

# %%
lrs = [2**x.item() for x in torch.arange(-20, -1)]

# %%
lrs
# Out:
# [9.5367431640625e-07,
#  1.9073486328125e-06,
#  3.814697265625e-06,
#  7.62939453125e-06,
#  1.52587890625e-05,
#  3.0517578125e-05,
#  6.103515625e-05,
#  0.0001220703125,
#  0.000244140625,
#  0.00048828125,
#  0.0009765625,
#  0.001953125,
#  0.00390625,
#  0.0078125,
#  0.015625,
#  0.03125,
#  0.0625,
#  0.125,
#  0.25]

# %%
for lr in lrs:
    print(f"###### {lr} ###### ")
    for name, (fan_in, fan_out) in NAME_TO_FAN_MAPPING.items():
        print(f"{name}: {lr * spectral_lr(fan_in, fan_out)}")
# Out:
# ###### 9.5367431640625e-07 ######
# token_embedding.weight: 1.52587890625e-05
# token_embedding.bias: 1.4901161193847656e-08
# qkv_proj.weight: 2.9802322387695312e-08
# qkv_proj.bias: 1.4551915228366852e-11
# o_proj.weight: 1.4901161193847656e-08
# o_proj.bias: 1.4551915228366852e-11
# gate_up_proj.weight: 1.1920928955078125e-07
# gate_up_proj.bias: 1.4551915228366852e-11
# down_proj.weight: 3.725290298461914e-09
# down_proj.bias: 3.637978807091713e-12
# lm_head.pp_block.weight: 7.152557373046875e-07
# ###### 1.9073486328125e-06 ######
# token_embedding.weight: 3.0517578125e-05
# token_embedding.bias: 2.9802322387695312e-08
# qkv_proj.weight: 5.960464477539063e-08
# qkv_proj.bias: 2.9103830456733704e-11
# o_proj.weight: 2.9802322387695312e-08
# o_proj.bias: 2.9103830456733704e-11
# gate_up_proj.weight: 2.384185791015625e-07
# gate_up_proj.bias: 2.9103830456733704e-11
# down_proj.weight: 7.450580596923828e-09
# down_proj.bias: 7.275957614183426e-12
# lm_head.pp_block.weight: 1.430511474609375e-06
# ###### 3.814697265625e-06 ######
# token_embedding.weight: 6.103515625e-05
# token_embedding.bias: 5.960464477539063e-08
# qkv_proj.weight: 1.1920928955078125e-07
# qkv_proj.bias: 5.820766091346741e-11
# o_proj.weight: 5.960464477539063e-08
# o_proj.bias: 5.820766091346741e-11
# gate_up_proj.weight: 4.76837158203125e-07
# gate_up_proj.bias: 5.820766091346741e-11
# down_proj.weight: 1.4901161193847656e-08
# down_proj.bias: 1.4551915228366852e-11
# lm_head.pp_block.weight: 2.86102294921875e-06
# ###### 7.62939453125e-06 ######
# token_embedding.weight: 0.0001220703125
# token_embedding.bias: 1.1920928955078125e-07
# qkv_proj.weight: 2.384185791015625e-07
# qkv_proj.bias: 1.1641532182693481e-10
# o_proj.weight: 1.1920928955078125e-07
# o_proj.bias: 1.1641532182693481e-10
# gate_up_proj.weight: 9.5367431640625e-07
# gate_up_proj.bias: 1.1641532182693481e-10
# down_proj.weight: 2.9802322387695312e-08
# down_proj.bias: 2.9103830456733704e-11
# lm_head.pp_block.weight: 5.7220458984375e-06
# ###### 1.52587890625e-05 ######
# token_embedding.weight: 0.000244140625
# token_embedding.bias: 2.384185791015625e-07
# qkv_proj.weight: 4.76837158203125e-07
# qkv_proj.bias: 2.3283064365386963e-10
# o_proj.weight: 2.384185791015625e-07
# o_proj.bias: 2.3283064365386963e-10
# gate_up_proj.weight: 1.9073486328125e-06
# gate_up_proj.bias: 2.3283064365386963e-10
# down_proj.weight: 5.960464477539063e-08
# down_proj.bias: 5.820766091346741e-11
# lm_head.pp_block.weight: 1.1444091796875e-05
# ###### 3.0517578125e-05 ######
# token_embedding.weight: 0.00048828125
# token_embedding.bias: 4.76837158203125e-07
# qkv_proj.weight: 9.5367431640625e-07
# qkv_proj.bias: 4.656612873077393e-10
# o_proj.weight: 4.76837158203125e-07
# o_proj.bias: 4.656612873077393e-10
# gate_up_proj.weight: 3.814697265625e-06
# gate_up_proj.bias: 4.656612873077393e-10
# down_proj.weight: 1.1920928955078125e-07
# down_proj.bias: 1.1641532182693481e-10
# lm_head.pp_block.weight: 2.288818359375e-05
# ###### 6.103515625e-05 ######
# token_embedding.weight: 0.0009765625
# token_embedding.bias: 9.5367431640625e-07
# qkv_proj.weight: 1.9073486328125e-06
# qkv_proj.bias: 9.313225746154785e-10
# o_proj.weight: 9.5367431640625e-07
# o_proj.bias: 9.313225746154785e-10
# gate_up_proj.weight: 7.62939453125e-06
# gate_up_proj.bias: 9.313225746154785e-10
# down_proj.weight: 2.384185791015625e-07
# down_proj.bias: 2.3283064365386963e-10
# lm_head.pp_block.weight: 4.57763671875e-05
# ###### 0.0001220703125 ######
# token_embedding.weight: 0.001953125
# token_embedding.bias: 1.9073486328125e-06
# qkv_proj.weight: 3.814697265625e-06
# qkv_proj.bias: 1.862645149230957e-09
# o_proj.weight: 1.9073486328125e-06
# o_proj.bias: 1.862645149230957e-09
# gate_up_proj.weight: 1.52587890625e-05
# gate_up_proj.bias: 1.862645149230957e-09
# down_proj.weight: 4.76837158203125e-07
# down_proj.bias: 4.656612873077393e-10
# lm_head.pp_block.weight: 9.1552734375e-05
# ###### 0.000244140625 ######
# token_embedding.weight: 0.00390625
# token_embedding.bias: 3.814697265625e-06
# qkv_proj.weight: 7.62939453125e-06
# qkv_proj.bias: 3.725290298461914e-09
# o_proj.weight: 3.814697265625e-06
# o_proj.bias: 3.725290298461914e-09
# gate_up_proj.weight: 3.0517578125e-05
# gate_up_proj.bias: 3.725290298461914e-09
# down_proj.weight: 9.5367431640625e-07
# down_proj.bias: 9.313225746154785e-10
# lm_head.pp_block.weight: 0.00018310546875
# ###### 0.00048828125 ######
# token_embedding.weight: 0.0078125
# token_embedding.bias: 7.62939453125e-06
# qkv_proj.weight: 1.52587890625e-05
# qkv_proj.bias: 7.450580596923828e-09
# o_proj.weight: 7.62939453125e-06
# o_proj.bias: 7.450580596923828e-09
# gate_up_proj.weight: 6.103515625e-05
# gate_up_proj.bias: 7.450580596923828e-09
# down_proj.weight: 1.9073486328125e-06
# down_proj.bias: 1.862645149230957e-09
# lm_head.pp_block.weight: 0.0003662109375
# ###### 0.0009765625 ######
# token_embedding.weight: 0.015625
# token_embedding.bias: 1.52587890625e-05
# qkv_proj.weight: 3.0517578125e-05
# qkv_proj.bias: 1.4901161193847656e-08
# o_proj.weight: 1.52587890625e-05
# o_proj.bias: 1.4901161193847656e-08
# gate_up_proj.weight: 0.0001220703125
# gate_up_proj.bias: 1.4901161193847656e-08
# down_proj.weight: 3.814697265625e-06
# down_proj.bias: 3.725290298461914e-09
# lm_head.pp_block.weight: 0.000732421875
# ###### 0.001953125 ######
# token_embedding.weight: 0.03125
# token_embedding.bias: 3.0517578125e-05
# qkv_proj.weight: 6.103515625e-05
# qkv_proj.bias: 2.9802322387695312e-08
# o_proj.weight: 3.0517578125e-05
# o_proj.bias: 2.9802322387695312e-08
# gate_up_proj.weight: 0.000244140625
# gate_up_proj.bias: 2.9802322387695312e-08
# down_proj.weight: 7.62939453125e-06
# down_proj.bias: 7.450580596923828e-09
# lm_head.pp_block.weight: 0.00146484375
# ###### 0.00390625 ######
# token_embedding.weight: 0.0625
# token_embedding.bias: 6.103515625e-05
# qkv_proj.weight: 0.0001220703125
# qkv_proj.bias: 5.960464477539063e-08
# o_proj.weight: 6.103515625e-05
# o_proj.bias: 5.960464477539063e-08
# gate_up_proj.weight: 0.00048828125
# gate_up_proj.bias: 5.960464477539063e-08
# down_proj.weight: 1.52587890625e-05
# down_proj.bias: 1.4901161193847656e-08
# lm_head.pp_block.weight: 0.0029296875
# ###### 0.0078125 ######
# token_embedding.weight: 0.125
# token_embedding.bias: 0.0001220703125
# qkv_proj.weight: 0.000244140625
# qkv_proj.bias: 1.1920928955078125e-07
# o_proj.weight: 0.0001220703125
# o_proj.bias: 1.1920928955078125e-07
# gate_up_proj.weight: 0.0009765625
# gate_up_proj.bias: 1.1920928955078125e-07
# down_proj.weight: 3.0517578125e-05
# down_proj.bias: 2.9802322387695312e-08
# lm_head.pp_block.weight: 0.005859375
# ###### 0.015625 ######
# token_embedding.weight: 0.25
# token_embedding.bias: 0.000244140625
# qkv_proj.weight: 0.00048828125
# qkv_proj.bias: 2.384185791015625e-07
# o_proj.weight: 0.000244140625
# o_proj.bias: 2.384185791015625e-07
# gate_up_proj.weight: 0.001953125
# gate_up_proj.bias: 2.384185791015625e-07
# down_proj.weight: 6.103515625e-05
# down_proj.bias: 5.960464477539063e-08
# lm_head.pp_block.weight: 0.01171875
# ###### 0.03125 ######
# token_embedding.weight: 0.5
# token_embedding.bias: 0.00048828125
# qkv_proj.weight: 0.0009765625
# qkv_proj.bias: 4.76837158203125e-07
# o_proj.weight: 0.00048828125
# o_proj.bias: 4.76837158203125e-07
# gate_up_proj.weight: 0.00390625
# gate_up_proj.bias: 4.76837158203125e-07
# down_proj.weight: 0.0001220703125
# down_proj.bias: 1.1920928955078125e-07
# lm_head.pp_block.weight: 0.0234375
# ###### 0.0625 ######
# token_embedding.weight: 1.0
# token_embedding.bias: 0.0009765625
# qkv_proj.weight: 0.001953125
# qkv_proj.bias: 9.5367431640625e-07
# o_proj.weight: 0.0009765625
# o_proj.bias: 9.5367431640625e-07
# gate_up_proj.weight: 0.0078125
# gate_up_proj.bias: 9.5367431640625e-07
# down_proj.weight: 0.000244140625
# down_proj.bias: 2.384185791015625e-07
# lm_head.pp_block.weight: 0.046875
# ###### 0.125 ######
# token_embedding.weight: 2.0
# token_embedding.bias: 0.001953125
# qkv_proj.weight: 0.00390625
# qkv_proj.bias: 1.9073486328125e-06
# o_proj.weight: 0.001953125
# o_proj.bias: 1.9073486328125e-06
# gate_up_proj.weight: 0.015625
# gate_up_proj.bias: 1.9073486328125e-06
# down_proj.weight: 0.00048828125
# down_proj.bias: 4.76837158203125e-07
# lm_head.pp_block.weight: 0.09375
# ###### 0.25 ######
# token_embedding.weight: 4.0
# token_embedding.bias: 0.00390625
# qkv_proj.weight: 0.0078125
# qkv_proj.bias: 3.814697265625e-06
# o_proj.weight: 0.00390625
# o_proj.bias: 3.814697265625e-06
# gate_up_proj.weight: 0.03125
# gate_up_proj.bias: 3.814697265625e-06
# down_proj.weight: 0.0009765625
# down_proj.bias: 9.5367431640625e-07
# lm_head.pp_block.weight: 0.1875

# %%
for name, (fan_in, fan_out) in NAME_TO_FAN_MAPPING.items():
    print(f"{name}: {0.001 * spectral_lr(fan_in, fan_out)}")
# Out:
# token_embedding.weight: 0.016
# token_embedding.bias: 1.5625e-05
# qkv_proj.weight: 3.125e-05
# qkv_proj.bias: 1.52587890625e-08
# o_proj.weight: 1.5625e-05
# o_proj.bias: 1.52587890625e-08
# gate_up_proj.weight: 0.000125
# gate_up_proj.bias: 1.52587890625e-08
# down_proj.weight: 3.90625e-06
# down_proj.bias: 3.814697265625e-09
# lm_head.pp_block.weight: 0.00075
