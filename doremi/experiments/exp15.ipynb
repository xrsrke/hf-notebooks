# %%
import sys
sys.path.append("/Users/huggingface/DATA/notebooks/hf-notebooks/doremi/experiments/")
import torch
from utils import plot_domain_weights, print_name_weights, get_mamba_dataset_weights, plot_domain_weights_comparison

# %%
weights_200k = torch.tensor([0.6908, 0.0513, 0.0986, 0.0029, 0.0598, 0.0222, 0.0014, 0.0041, 0.0030,
        0.0021, 0.0024, 0.0235, 0.0090, 0.0014, 0.0031, 0.0245])

# %%
print_name_weights(weights=weights_200k)
# Out:
# fineweb tensor(0.6908)
# stack_full tensor(0.0513)
# c4 tensor(0.0986)
# arxiv tensor(0.0029)
# synthetic-data tensor(0.0598)
# stack-pull-requests tensor(0.0222)
# stack-jupyter-scripts tensor(0.0014)
# stack-jupyter-structured tensor(0.0041)
# open-web-math tensor(0.0030)
# stack-issues tensor(0.0021)
# stackoverflow tensor(0.0024)
# wikipedia tensor(0.0235)
# project-gutenberg tensor(0.0090)
# deepmind-math tensor(0.0014)
# stack-kaggle-scripts tensor(0.0031)
# stack-documentation tensor(0.0245)
# ----- sorthing bellow ---
# fineweb tensor(0.6908) tensor(0)
# c4 tensor(0.0986) tensor(2)
# synthetic-data tensor(0.0598) tensor(4)
# stack_full tensor(0.0513) tensor(1)
# stack-documentation tensor(0.0245) tensor(15)
# wikipedia tensor(0.0235) tensor(11)
# stack-pull-requests tensor(0.0222) tensor(5)
# project-gutenberg tensor(0.0090) tensor(12)
# stack-jupyter-structured tensor(0.0041) tensor(7)
# stack-kaggle-scripts tensor(0.0031) tensor(14)
# open-web-math tensor(0.0030) tensor(8)
# arxiv tensor(0.0029) tensor(3)
# stackoverflow tensor(0.0024) tensor(10)
# stack-issues tensor(0.0021) tensor(9)
# deepmind-math tensor(0.0014) tensor(13)
# stack-jupyter-scripts tensor(0.0014) tensor(6)

# %%
plot_domain_weights(weights=weights_200k)
