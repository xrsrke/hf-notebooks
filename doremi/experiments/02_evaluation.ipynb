# %%
doremi_data = {
'arc:challenge': {'acc': 0.186, 'acc_stderr': 0.0123107902084128, 'acc_norm': 0.245, 'acc_norm_stderr': 0.013607356839598116},
'arc:easy': {'acc': 0.41, 'acc_stderr': 0.015560917136921672, 'acc_norm': 0.42, 'acc_norm_stderr': 0.015615500115072957},
'commonsense_qa': {'acc': 0.275, 'acc_stderr': 0.014127086556490526, 'acc_norm': 0.283, 'acc_norm_stderr': 0.014251810906481723},
'hellaswag': {'acc': 0.319, 'acc_stderr': 0.01474640486547349, 'acc_norm': 0.33, 'acc_norm_stderr': 0.014876872027456738},
'mmlu:abstract_algebra': {'acc': 0.14, 'acc_stderr': 0.03487350880197771, 'acc_norm': 0.15, 'acc_norm_stderr': 0.035887028128263714},
'mmlu:anatomy': {'acc': 0.2518518518518518, 'acc_stderr': 0.0374985070917402, 'acc_norm': 0.23703703703703705, 'acc_norm_stderr': 0.03673731683969506},
'mmlu:astronomy': {'acc': 0.2236842105263158, 'acc_stderr': 0.033911609343436025, 'acc_norm': 0.28289473684210525, 'acc_norm_stderr': 0.03665349695640767},
'mmlu:business_ethics': {'acc': 0.45, 'acc_stderr': 0.05, 'acc_norm': 0.36, 'acc_norm_stderr': 0.04824181513244218},
'mmlu:clinical_knowledge': {'acc': 0.20754716981132076, 'acc_stderr': 0.024959918028911274, 'acc_norm': 0.2981132075471698, 'acc_norm_stderr': 0.02815283794249386},
'mmlu:college_biology': {'acc': 0.2916666666666667, 'acc_stderr': 0.038009680605548574, 'acc_norm': 0.2638888888888889, 'acc_norm_stderr': 0.03685651095897532},
'mmlu:college_chemistry': {'acc': 0.28, 'acc_stderr': 0.04512608598542127, 'acc_norm': 0.27, 'acc_norm_stderr': 0.0446196043338474},
'mmlu:college_computer_science': {'acc': 0.26, 'acc_stderr': 0.0440844002276808, 'acc_norm': 0.27, 'acc_norm_stderr': 0.0446196043338474},
'mmlu:college_mathematics': {'acc': 0.14, 'acc_stderr': 0.03487350880197771, 'acc_norm': 0.24, 'acc_norm_stderr': 0.04292346959909282},
'mmlu:college_medicine': {'acc': 0.2543352601156069, 'acc_stderr': 0.0332055644308557, 'acc_norm': 0.2254335260115607, 'acc_norm_stderr': 0.03186209851641143},
'mmlu:college_physics': {'acc': 0.21568627450980393, 'acc_stderr': 0.04092563958237655, 'acc_norm': 0.17647058823529413, 'acc_norm_stderr': 0.03793281185307809},
'mmlu:computer_security': {'acc': 0.27, 'acc_stderr': 0.044619604333847394, 'acc_norm': 0.29, 'acc_norm_stderr': 0.045604802157206845},
'mmlu:conceptual_physics': {'acc': 0.3191489361702128, 'acc_stderr': 0.03047297336338005, 'acc_norm': 0.22127659574468084, 'acc_norm_stderr': 0.027136349602424063},
'mmlu:econometrics': {'acc': 0.21052631578947367, 'acc_stderr': 0.0383515395439942, 'acc_norm': 0.21929824561403508, 'acc_norm_stderr': 0.038924311065187546},
'mmlu:electrical_engineering': {'acc': 0.2482758620689655, 'acc_stderr': 0.03600105692727771, 'acc_norm': 0.2620689655172414, 'acc_norm_stderr': 0.036646663372252565},
'mmlu:elementary_mathematics': {'acc': 0.2275132275132275, 'acc_stderr': 0.02159126940782378, 'acc_norm': 0.2328042328042328, 'acc_norm_stderr': 0.02176596167215453},
'mmlu:formal_logic': {'acc': 0.2619047619047619, 'acc_stderr': 0.039325376803928724, 'acc_norm': 0.23015873015873015, 'acc_norm_stderr': 0.03764950879790606},
'mmlu:global_facts': {'acc': 0.15, 'acc_stderr': 0.0358870281282637, 'acc_norm': 0.16, 'acc_norm_stderr': 0.03684529491774709},
'mmlu:high_school_biology': {'acc': 0.21935483870967742, 'acc_stderr': 0.023540799358723302, 'acc_norm': 0.2903225806451613, 'acc_norm_stderr': 0.025822106119415898},
'mmlu:high_school_chemistry': {'acc': 0.19704433497536947, 'acc_stderr': 0.027986724666736212, 'acc_norm': 0.21674876847290642, 'acc_norm_stderr': 0.02899033125251624},
'mmlu:high_school_computer_science': {'acc': 0.27, 'acc_stderr': 0.04461960433384741, 'acc_norm': 0.31, 'acc_norm_stderr': 0.04648231987117316},
'mmlu:high_school_european_history': {'acc': 0.19393939393939394, 'acc_stderr': 0.030874145136562094, 'acc_norm': 0.30303030303030304, 'acc_norm_stderr': 0.03588624800091707},
'mmlu:high_school_geography': {'acc': 0.2474747474747475, 'acc_stderr': 0.0307463007421245, 'acc_norm': 0.29797979797979796, 'acc_norm_stderr': 0.03258630383836554},
'mmlu:high_school_government_and_politics': {'acc': 0.24352331606217617, 'acc_stderr': 0.030975436386845436, 'acc_norm': 0.2849740932642487, 'acc_norm_stderr': 0.03257714077709662},
'mmlu:high_school_macroeconomics': {'acc': 0.24102564102564103, 'acc_stderr': 0.02168554666533319, 'acc_norm': 0.23846153846153847, 'acc_norm_stderr': 0.02160629449464773},
'mmlu:high_school_mathematics': {'acc': 0.14074074074074075, 'acc_stderr': 0.021202930343568804, 'acc_norm': 0.2037037037037037, 'acc_norm_stderr': 0.02455617221914127},
'mmlu:high_school_microeconomics': {'acc': 0.24369747899159663, 'acc_stderr': 0.027886828078380582, 'acc_norm': 0.35294117647058826, 'acc_norm_stderr': 0.031041941304059288},
'mmlu:high_school_physics': {'acc': 0.2582781456953642, 'acc_stderr': 0.035737053147634576, 'acc_norm': 0.2913907284768212, 'acc_norm_stderr': 0.03710185726119995},
'mmlu:high_school_psychology': {'acc': 0.3247706422018349, 'acc_stderr': 0.02007772910931033, 'acc_norm': 0.29541284403669726, 'acc_norm_stderr': 0.019560619182976},
'mmlu:high_school_statistics': {'acc': 0.27314814814814814, 'acc_stderr': 0.030388051301678116, 'acc_norm': 0.2824074074074074, 'acc_norm_stderr': 0.030701372111510927},
'mmlu:high_school_us_history': {'acc': 0.2549019607843137, 'acc_stderr': 0.030587591351604257, 'acc_norm': 0.3088235294117647, 'acc_norm_stderr': 0.03242661719827218},
'mmlu:high_school_world_history': {'acc': 0.20253164556962025, 'acc_stderr': 0.026160568246601464, 'acc_norm': 0.25316455696202533, 'acc_norm_stderr': 0.028304657943035286},
'mmlu:human_aging': {'acc': 0.34080717488789236, 'acc_stderr': 0.0318114974705536, 'acc_norm': 0.27802690582959644, 'acc_norm_stderr': 0.03006958487449403},
'mmlu:human_sexuality': {'acc': 0.3511450381679389, 'acc_stderr': 0.04186445163013751, 'acc_norm': 0.3053435114503817, 'acc_norm_stderr': 0.04039314978724561},
'mmlu:international_law': {'acc': 0.14049586776859505, 'acc_stderr': 0.03172233426002159, 'acc_norm': 0.2231404958677686, 'acc_norm_stderr': 0.03800754475228733},
'mmlu:jurisprudence': {'acc': 0.18518518518518517, 'acc_stderr': 0.03755265865037181, 'acc_norm': 0.25, 'acc_norm_stderr': 0.04186091791394607},
'mmlu:logical_fallacies': {'acc': 0.25766871165644173, 'acc_stderr': 0.03436150827846917, 'acc_norm': 0.3374233128834356, 'acc_norm_stderr': 0.03714908409935575},
'mmlu:machine_learning': {'acc': 0.2767857142857143, 'acc_stderr': 0.042466243366976256, 'acc_norm': 0.25892857142857145, 'acc_norm_stderr': 0.041577515398656284},
'mmlu:management': {'acc': 0.27184466019417475, 'acc_stderr': 0.044052680241409216, 'acc_norm': 0.33980582524271846, 'acc_norm_stderr': 0.046897659372781335},
'mmlu:marketing': {'acc': 0.3717948717948718, 'acc_stderr': 0.031660988918880785, 'acc_norm': 0.37606837606837606, 'acc_norm_stderr': 0.03173393632969482},
'mmlu:medical_genetics': {'acc': 0.27, 'acc_stderr': 0.044619604333847394, 'acc_norm': 0.28, 'acc_norm_stderr': 0.04512608598542127},
'mmlu:miscellaneous': {'acc': 0.3243933588761175, 'acc_stderr': 0.016740929047162692, 'acc_norm': 0.30395913154533843, 'acc_norm_stderr': 0.016448321686769046},
'mmlu:moral_disputes': {'acc': 0.2254335260115607, 'acc_stderr': 0.022497230190967547, 'acc_norm': 0.21098265895953758, 'acc_norm_stderr': 0.021966309947043124},
'mmlu:moral_scenarios': {'acc': 0.23798882681564246, 'acc_stderr': 0.014242630070574915, 'acc_norm': 0.27262569832402234, 'acc_norm_stderr': 0.014893391735249588},
'mmlu:nutrition': {'acc': 0.21895424836601307, 'acc_stderr': 0.02367908986180772, 'acc_norm': 0.2647058823529412, 'acc_norm_stderr': 0.02526169121972948},
'mmlu:philosophy': {'acc': 0.22508038585209003, 'acc_stderr': 0.023720088516179027, 'acc_norm': 0.26688102893890675, 'acc_norm_stderr': 0.02512263760881664},
'mmlu:prehistory': {'acc': 0.2623456790123457, 'acc_stderr': 0.024477222856135124, 'acc_norm': 0.19135802469135801, 'acc_norm_stderr': 0.021887704613396165},
'mmlu:professional_accounting': {'acc': 0.24468085106382978, 'acc_stderr': 0.025645553622266726, 'acc_norm': 0.25177304964539005, 'acc_norm_stderr': 0.025892151156709405},
'mmlu:professional_law': {'acc': 0.244, 'acc_stderr': 0.013588548437881431, 'acc_norm': 0.269, 'acc_norm_stderr': 0.014029819522568196},
'mmlu:professional_medicine': {'acc': 0.25, 'acc_stderr': 0.026303648393696036, 'acc_norm': 0.2610294117647059, 'acc_norm_stderr': 0.02667925227010311},
'mmlu:professional_psychology': {'acc': 0.2647058823529412, 'acc_stderr': 0.01784808957491323, 'acc_norm': 0.2565359477124183, 'acc_norm_stderr': 0.01766784161237899},
'mmlu:public_relations': {'acc': 0.36363636363636365, 'acc_stderr': 0.04607582090719976, 'acc_norm': 0.22727272727272727, 'acc_norm_stderr': 0.04013964554072773},
'mmlu:security_studies': {'acc': 0.3142857142857143, 'acc_stderr': 0.02971932942241746, 'acc_norm': 0.20408163265306123, 'acc_norm_stderr': 0.025801283475090496},
'mmlu:sociology': {'acc': 0.22388059701492538, 'acc_stderr': 0.029475250236017197, 'acc_norm': 0.22885572},
'mmlu:us_foreign_policy': {'acc': 0.24, 'acc_stderr': 0.042923469599092816, 'acc_norm': 0.23, 'acc_norm_stderr': 0.04229525846816503},
'mmlu:virology': {'acc': 0.25903614457831325, 'acc_stderr': 0.034106466140718564, 'acc_norm': 0.3072289156626506, 'acc_norm_stderr': 0.03591566797824664},
'mmlu:world_religions': {'acc': 0.2222222222222222, 'acc_stderr': 0.03188578017686398, 'acc_norm': 0.28654970760233917, 'acc_norm_stderr': 0.034678266857038266},
'openbookqa': {'acc': 0.156, 'acc_stderr': 0.01624363602839108, 'acc_norm': 0.28, 'acc_norm_stderr': 0.020099950647503233},
'piqa': {'acc': 0.644, 'acc_stderr': 0.015149042659306628, 'acc_norm': 0.659, 'acc_norm_stderr': 0.014998131348402714},
'siqa': {'acc': 0.376, 'acc_stderr': 0.01532510550889813, 'acc_norm': 0.403, 'acc_norm_stderr': 0.015518757419066533},
'winogrande': {'acc': 0.522, 'acc_stderr': 0.01580397942816195, 'acc_norm': 0.504, 'acc_norm_stderr': 0.015818793703510886},
'arc:_average': {'acc': 0.298, 'acc_stderr': 0.013935853672667236, 'acc_norm': 0.3325, 'acc_norm_stderr': 0.014611428477335537},
'mmlu:_average': {'acc': 0.2508586420223811, 'acc_stderr': 0.032091713938279885, 'acc_norm': 0.263164602105495, 'acc_norm_stderr': 0.03277023638625347}
}

# %%
# mmlu:us_foreign_policy": {"acc": 0.23, "acc_stderr": 0.04229525846816506, "acc_norm": 0.24, "acc_norm_stderr": 0.04292346959909284},
# "mmlu:virology": {"acc": 0.26506024096385544, "acc_stderr": 0.03436024037944967, "acc_norm": 0.3072289156626506, "acc_norm_stderr": 0.03591566797824665}}

# %%
reference_data = {
"arc:challenge": {"acc": 0.2, "acc_stderr": 0.012655439943366641, "acc_norm": 0.255, "acc_norm_stderr": 0.013790038620872832},
"arc:easy": {"acc": 0.452, "acc_stderr": 0.01574623586588068, "acc_norm": 0.416, "acc_norm_stderr": 0.015594460144140603},
"commonsense_qa": {"acc": 0.269, "acc_stderr": 0.014029819522568193, "acc_norm": 0.293, "acc_norm_stderr": 0.01439994299844127},
"hellaswag": {"acc": 0.331, "acc_stderr": 0.014888272588203938, "acc_norm": 0.364, "acc_norm_stderr": 0.015222868840522022},
"mmlu:abstract_algebra": {"acc": 0.22, "acc_stderr": 0.0416333199893227, "acc_norm": 0.25, "acc_norm_stderr": 0.04351941398892446},
"mmlu:management": {"acc": 0.2621359223300971, "acc_stderr": 0.043546310772605935, "acc_norm": 0.3592233009708738, "acc_norm_stderr": 0.04750458399041693},
"mmlu:marketing": {"acc": 0.36324786324786323, "acc_stderr": 0.03150712523091264, "acc_norm": 0.3717948717948718, "acc_norm_stderr": 0.03166098891888077},
"mmlu:medical_genetics": {"acc": 0.27, "acc_stderr": 0.044619604333847394, "acc_norm": 0.31, "acc_norm_stderr": 0.04648231987117316},
"mmlu:miscellaneous": {"acc": 0.31417624521072796, "acc_stderr": 0.016599291735884904, "acc_norm": 0.3128991060025543, "acc_norm_stderr": 0.016580935940304034},
"mmlu:moral_disputes": {"acc": 0.23121387283236994, "acc_stderr": 0.022698657167855716, "acc_norm": 0.21676300578034682, "acc_norm_stderr": 0.022183477668412853},
"mmlu:moral_scenarios": {"acc": 0.23798882681564246, "acc_stderr": 0.014242630070574915, "acc_norm": 0.27262569832402234, "acc_norm_stderr": 0.014893391735249588},
"mmlu:nutrition": {"acc": 0.238562091503268, "acc_stderr": 0.024404394928087877, "acc_norm": 0.28431372549019607, "acc_norm_stderr": 0.02582916327275748},
"mmlu:philosophy": {"acc": 0.2347266881028939, "acc_stderr": 0.024071805887677048, "acc_norm": 0.2765273311897106, "acc_norm_stderr": 0.02540383297817962},
"mmlu:prehistory": {"acc": 0.2839506172839506, "acc_stderr": 0.025089478523765127, "acc_norm": 0.20987654320987653, "acc_norm_stderr": 0.02265834408598137},
"mmlu:professional_accounting": {"acc": 0.2730496453900709, "acc_stderr": 0.026577860943307857, "acc_norm": 0.2624113475177305, "acc_norm_stderr": 0.026244920349843},
"mmlu:professional_law": {"acc": 0.249, "acc_stderr": 0.013681600278702301, "acc_norm": 0.261, "acc_norm_stderr": 0.013895037677965127},
"mmlu:professional_medicine": {"acc": 0.24632352941176472, "acc_stderr": 0.02617343857052, "acc_norm": 0.25735294117647056, "acc_norm_stderr": 0.026556519470041524},
"mmlu:professional_psychology": {"acc": 0.2647058823529412, "acc_stderr": 0.017848089574913226, "acc_norm": 0.2647058823529412, "acc_norm_stderr": 0.01784808957491322},
"mmlu:public_relations": {"acc": 0.35454545454545455, "acc_stderr": 0.04582004841505417, "acc_norm": 0.21818181818181817, "acc_norm_stderr": 0.039559328617958335},
"mmlu:security_studies": {"acc": 0.3224489795918367, "acc_stderr": 0.029923100563683913, "acc_norm": 0.2, "acc_norm_stderr": 0.025607375986579157},
"mmlu:sociology": {"acc": 0.23383084577114427, "acc_stderr": 0.029929415408348387, "acc_norm": 0.22388059701492538, "acc_norm_stderr": 0.0294752502360172},
'mmlu:us_foreign_policy': {'acc': 0.23, 'acc_stderr': 0.04229525846816506, 'acc_norm': 0.24, 'acc_norm_stderr': 0.04292346959909284},
'mmlu:virology': {'acc': 0.26506024096385544, 'acc_stderr': 0.03436024037944967, 'acc_norm': 0.3072289156626506, 'acc_norm_stderr': 0.03591566797824665},
'mmlu:world_religions': {'acc': 0.2222222222222222, 'acc_stderr': 0.03188578017686398, 'acc_norm': 0.2631578947368421, 'acc_norm_stderr': 0.033773102522091945},
'openbookqa': {'acc': 0.148, 'acc_stderr': 0.015896458561251242, 'acc_norm': 0.268, 'acc_norm_stderr': 0.019827714859587578},
'piqa': {'acc': 0.646, 'acc_stderr': 0.015129868238451772, 'acc_norm': 0.666, 'acc_norm_stderr': 0.014922019523732963},
'siqa': {'acc': 0.379, 'acc_stderr': 0.01534909100222535, 'acc_norm': 0.4, 'acc_norm_stderr': 0.015499685165842592},
'winogrande': {'acc': 0.511, 'acc_stderr': 0.015815471195292686, 'acc_norm': 0.494, 'acc_norm_stderr': 0.015818160898606715},
'arc:_average': {'acc': 0.326, 'acc_stderr': 0.014200837904623662, 'acc_norm': 0.3355, 'acc_norm_stderr': 0.014692249382506718},
'mmlu:_average': {'acc': 0.255831349791023, 'acc_stderr': 0.03237110342564199, 'acc_norm': 0.2710750729392303, 'acc_norm_stderr': 0.03317269465935651}
}

# %%
doremi_padding_data = {
    "arc:_average": {"acc": 0.3190, "acc_norm": 0.3310},
    "arc:challenge": {"acc": 0.2000, "acc_norm": 0.2430},
    "arc:easy": {"acc": 0.4380, "acc_norm": 0.4190},
    "commonsense_qa": {"acc": 0.2630, "acc_norm": 0.2880},
    "hellaswag": {"acc": 0.3200, "acc_norm": 0.3510},
    "mmlu:_average": {"acc": 0.2547, "acc_norm": 0.2663},
    "mmlu:abstract_algebra": {"acc": 0.2100, "acc_norm": 0.1800},
    "mmlu:anatomy": {"acc": 0.2963, "acc_norm": 0.2667},
    "mmlu:astronomy": {"acc": 0.2303, "acc_norm": 0.2961},
    "mmlu:business_ethics": {"acc": 0.4400, "acc_norm": 0.3300},
    "mmlu:clinical_knowledge": {"acc": 0.2302, "acc_norm": 0.3057},
    "mmlu:college_biology": {"acc": 0.2708, "acc_norm": 0.2500},
    "mmlu:college_chemistry": {"acc": 0.3400, "acc_norm": 0.3100},
    "mmlu:college_computer_science": {"acc": 0.2400, "acc_norm": 0.2600},
    "mmlu:college_mathematics": {"acc": 0.1700, "acc_norm": 0.2400},
    "mmlu:college_medicine": {"acc": 0.3006, "acc_norm": 0.2139},
    "mmlu:college_physics": {"acc": 0.2353, "acc_norm": 0.2059},
    "mmlu:computer_security": {"acc": 0.2300, "acc_norm": 0.2900},
    "mmlu:conceptual_physics": {"acc": 0.3191, "acc_norm": 0.2298},
    "mmlu:econometrics": {"acc": 0.2193, "acc_norm": 0.1930},
    "mmlu:electrical_engineering": {"acc": 0.2621, "acc_norm": 0.2828},
    "mmlu:elementary_mathematics": {"acc": 0.2249, "acc_norm": 0.2328},
    "mmlu:formal_logic": {"acc": 0.2540, "acc_norm": 0.2222},
    "mmlu:global_facts": {"acc": 0.2000, "acc_norm": 0.2100},
    "mmlu:high_school_biology": {"acc": 0.2387, "acc_norm": 0.2839},
    "mmlu:high_school_chemistry": {"acc": 0.1773, "acc_norm": 0.2266},
    "mmlu:high_school_computer_science": {"acc": 0.2500, "acc_norm": 0.3000},
    "mmlu:high_school_european_history": {"acc": 0.2424, "acc_norm": 0.3455},
    "mmlu:high_school_geography": {"acc": 0.2626, "acc_norm": 0.3333},
    "mmlu:high_school_government_and_politics": {"acc": 0.2435, "acc_norm": 0.2746},
    "mmlu:high_school_macroeconomics": {"acc": 0.2359, "acc_norm": 0.2359},
    "mmlu:high_school_mathematics": {"acc": 0.1370, "acc_norm": 0.2000},
    "mmlu:high_school_microeconomics": {"acc": 0.2395, "acc_norm": 0.3319},
    "mmlu:high_school_physics": {"acc": 0.3245, "acc_norm": 0.3245},
    "mmlu:high_school_psychology": {"acc": 0.3028, "acc_norm": 0.2844},
    "mmlu:high_school_statistics": {"acc": 0.2685, "acc_norm": 0.3056},
    "mmlu:high_school_us_history": {"acc": 0.2451, "acc_norm": 0.3284},
    "mmlu:high_school_world_history": {"acc": 0.2278, "acc_norm": 0.2616},
    "mmlu:human_aging": {"acc": 0.3318, "acc_norm": 0.2960},
    "mmlu:human_sexuality": {"acc": 0.3664, "acc_norm": 0.2977},
    "mmlu:international_law": {"acc": 0.1653, "acc_norm": 0.2562},
    "mmlu:jurisprudence": {"acc": 0.1481, "acc_norm": 0.2130},
    "mmlu:logical_fallacies": {"acc": 0.2393, "acc_norm": 0.3313},
    "mmlu:machine_learning": {"acc": 0.2768, "acc_norm": 0.2857},
    "mmlu:management": {"acc": 0.2621, "acc_norm": 0.3301},
    "mmlu:marketing": {"acc": 0.3632, "acc_norm": 0.3932},
    "mmlu:medical_genetics": {"acc": 0.2400, "acc_norm": 0.2900},
    "mmlu:miscellaneous": {"acc": 0.3155, "acc_norm": 0.3052},
    "mmlu:moral_disputes": {"acc": 0.2081, "acc_norm": 0.1994},
    "mmlu:moral_scenarios": {"acc": 0.2380, "acc_norm": 0.2726},
    "mmlu:nutrition": {"acc": 0.2190, "acc_norm": 0.2876},
    "mmlu:philosophy": {"acc": 0.2347, "acc_norm": 0.2605},
    "mmlu:prehistory": {"acc": 0.2716, "acc_norm": 0.1821},
    "mmlu:professional_accounting": {"acc": 0.2624, "acc_norm": 0.2376},
    "mmlu:professional_law": {"acc": 0.2420, "acc_norm": 0.2480},
    "mmlu:professional_medicine": {"acc": 0.2684, "acc_norm": 0.2647},
    "mmlu:professional_psychology": {"acc": 0.2614, "acc_norm": 0.2418},
    "mmlu:public_relations": {"acc": 0.3545, "acc_norm": 0.2455},
    "mmlu:security_studies": {"acc": 0.3061, "acc_norm": 0.1959},
    "mmlu:sociology": {"acc": 0.2438, "acc_norm": 0.2338},
    "mmlu:us_foreign_policy": {"acc": 0.2400, "acc_norm": 0.2100},
    "mmlu:virology": {"acc": 0.2289, "acc_norm": 0.2892},
    "mmlu:world_religions": {"acc": 0.1637, "acc_norm": 0.2573},
    "openbookqa": {"acc": 0.1400, "acc_norm": 0.2920},
    "piqa": {"acc": 0.6400, "acc_norm": 0.6750},
    "siqa": {"acc": 0.3750, "acc_norm": 0.3920},
    "winogrande": {"acc": 0.5250, "acc_norm": 0.5070}
}

# %%
def compute_stats(doremi, reference):
    total = 0
    succeed = 0
    same = 0
    
    for name in doremi:
        tuned_acc = doremi[name]['acc']
        ref_acc = reference[name]['acc']
    
        if tuned_acc > ref_acc:
            succeed += 1
        elif tuned_acc == ref_acc:
            same += 1
    
        total += 1

    failed = total - succeed - same

    print(f"total={total}, succeed={succeed}, failed={failed}, same={same}")

# %%
compute_stats(doremi_data, reference_data)
# Out:
# total=67, succeed=22, failed=36, same=9

# %%
compute_stats(doremi_padding_data, reference_data)
# Out:
# total=67, succeed=28, failed=38, same=1

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)

tasks = list(doremi_data.keys())
columns = ['Task', 'DoReMi ACC', 'Reference ACC', 'DoReMi AccNorm', 'Reference AccNorm']
data = []

for task in tasks:
    row = [
        task,
        doremi_data[task]['acc'],
        reference_data[task]['acc'],
        doremi_data[task].get('acc_norm', 'N/A'),  # Using 'N/A' for missing 'acc_norm' values
        reference_data[task].get('acc_norm', 'N/A')
    ]
    data.append(row)

# Create DataFrame
comparison_df = pd.DataFrame(data, columns=columns)

# %%
comparison_df
# Out:
#                                         Task  DoReMi ACC  Reference ACC  \
# 0                              arc:challenge    0.186000       0.200000
# 1                                   arc:easy    0.410000       0.452000
# 2                             commonsense_qa    0.275000       0.269000
# 3                                  hellaswag    0.319000       0.331000
# 4                      mmlu:abstract_algebra    0.140000       0.220000
# 5                               mmlu:anatomy    0.251852       0.325926
# 6                             mmlu:astronomy    0.223684       0.203947
# 7                       mmlu:business_ethics    0.450000       0.460000
# 8                    mmlu:clinical_knowledge    0.207547       0.222642
# 9                       mmlu:college_biology    0.291667       0.284722
# 10                    mmlu:college_chemistry    0.280000       0.290000
# 11             mmlu:college_computer_science    0.260000       0.230000
# ...

# %%
def highlight_greater_doremi_acc(row):
    if row['DoReMi ACC'] > row['Reference ACC']:
        return ['background-color: #59cc0c'] * len(row)  # Apply yellow background to entire row
    elif row['DoReMi ACC'] == row['Reference ACC']:
        return ['background-color: #cc9c0c'] * len(row)  # Apply yellow background to entire row
    else:
        return [''] * len(row)  # No styling for rows that don't meet the condition

# Apply the styling function to the DataFrame
styled_df = comparison_df.style.apply(highlight_greater_doremi_acc, axis=1)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# ...

# %%
proxy model was trained for 25k steps due to ran out of training data, both 1b model was trained for 200k steps

experiment 1: raw domain weights: (domain project-gutenberg has 0.0014, this domain don't have any samples in the 1b training due to small weight) vs reference weight
the number of tasks that doremi outperofrm the reference model: 19
the number of tasks that under performance 31
the number of tasks that have equal perofrmance : 8

experiment 2: i adjust the weight of domain project-gutenberg a bit, make it have 1 sample, and subtract the fineweb one sample:
the number of tasks it outperofmace refernce: 28
the number of task it underperofrmance: 38
number of tasks that have equal performance: 1


reference weights are based on the ratio of tokens on each domain
# Out:
#   Cell In[137], line 1
#     proxy model was trained for 25k steps, due to ran out of training data, both 1b model was trained for 200k steps
#           ^
# SyntaxError: invalid syntax

# %%
proxy model was trained for 25k steps, due to ran out of training data, both 1b model was trained for 200k steps

the number of tasks that doremi outperofrm the reference model: 19
the number of tasks that under performance 31
the number of tasks that have equal perofrmance : 8
