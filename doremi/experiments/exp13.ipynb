# %%
import sys
sys.path.append("/Users/huggingface/DATA/notebooks/hf-notebooks/doremi/experiments/")
import torch
from utils import plot_domain_weights, print_name_weights, get_mamba_dataset_weights, plot_domain_weights_comparison

# %%
weights_200k = torch.tensor([6.9301e-01, 6.5236e-02, 1.4352e-01, 4.7325e-03, 3.1457e-02, 1.4485e-02,
        1.4739e-03, 5.3138e-03, 5.6996e-03, 3.2463e-03, 3.6926e-03, 7.7788e-03,
        6.2274e-03, 6.8413e-04, 2.3718e-03, 1.1075e-02])

# %%
print_name_weights(weights=weights_200k)
# Out:
# fineweb tensor(0.6930)
# stack_full tensor(0.0652)
# c4 tensor(0.1435)
# arxiv tensor(0.0047)
# synthetic-data tensor(0.0315)
# stack-pull-requests tensor(0.0145)
# stack-jupyter-scripts tensor(0.0015)
# stack-jupyter-structured tensor(0.0053)
# open-web-math tensor(0.0057)
# stack-issues tensor(0.0032)
# stackoverflow tensor(0.0037)
# wikipedia tensor(0.0078)
# project-gutenberg tensor(0.0062)
# deepmind-math tensor(0.0007)
# stack-kaggle-scripts tensor(0.0024)
# stack-documentation tensor(0.0111)
# ----- sorthing bellow ---
# fineweb tensor(0.6930) tensor(0)
# c4 tensor(0.1435) tensor(2)
# stack_full tensor(0.0652) tensor(1)
# synthetic-data tensor(0.0315) tensor(4)
# stack-pull-requests tensor(0.0145) tensor(5)
# stack-documentation tensor(0.0111) tensor(15)
# wikipedia tensor(0.0078) tensor(11)
# project-gutenberg tensor(0.0062) tensor(12)
# open-web-math tensor(0.0057) tensor(8)
# stack-jupyter-structured tensor(0.0053) tensor(7)
# arxiv tensor(0.0047) tensor(3)
# stackoverflow tensor(0.0037) tensor(10)
# stack-issues tensor(0.0032) tensor(9)
# stack-kaggle-scripts tensor(0.0024) tensor(14)
# stack-jupyter-scripts tensor(0.0015) tensor(6)
# deepmind-math tensor(0.0007) tensor(13)

# %%
plot_domain_weights(weights=weights_200k)
