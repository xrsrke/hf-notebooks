# %% [markdown]
# ### 1B at 110k

# %%
import sys
sys.path.append("/Users/huggingface/DATA/notebooks/hf-notebooks/doremi/experiments/")
from utils import plot_domain_weights, print_name_weights, compute_eval_stats, plot_eval, compute_avg_eval
from constants import REFERENCE_1B_110K_TOKEN_RATIO, REFERENCE_1B_200K_UNIFORM, REFERENCE_1B_200K_TOKEN_RATIO, REFERENCE_1B_200K_TOKEN_RATIO

# %%
DOREMI_1B_110K = {
"arc:challenge": {
"acc": 0.198,
"acc_stderr": 0.012607733934175297,
"acc_norm": 0.251,
"acc_norm_stderr": 0.01371813351688892
},
"arc:easy": {
"acc": 0.444,
"acc_stderr": 0.015719768163402086,
"acc_norm": 0.416,
"acc_norm_stderr": 0.015594460144140603
},
"commonsense_qa": {
"acc": 0.277,
"acc_stderr": 0.014158794845306263,
"acc_norm": 0.287,
"acc_norm_stderr": 0.014312087053809968
},
"hellaswag": {
"acc": 0.318,
"acc_stderr": 0.014734079309311901,
"acc_norm": 0.355,
"acc_norm_stderr": 0.015139491543780529
},
"mmlu:abstract_algebra": {
"acc": 0.15,
"acc_stderr": 0.03588702812826369,
"acc_norm": 0.16,
"acc_norm_stderr": 0.03684529491774709
},
"mmlu:anatomy": {
"acc": 0.31851851851851853,
"acc_stderr": 0.0402477840197711,
"acc_norm": 0.3037037037037037,
"acc_norm_stderr": 0.039725528847851375
},
"mmlu:astronomy": {
"acc": 0.2236842105263158,
"acc_stderr": 0.033911609343436025,
"acc_norm": 0.2631578947368421,
"acc_norm_stderr": 0.03583496176361062
},
"mmlu:business_ethics": {
"acc": 0.5,
"acc_stderr": 0.050251890762960605,
"acc_norm": 0.4,
"acc_norm_stderr": 0.04923659639173309
},
"mmlu:clinical_knowledge": {
"acc": 0.22264150943396227,
"acc_stderr": 0.025604233470899105,
"acc_norm": 0.2943396226415094,
"acc_norm_stderr": 0.028049186315695245
},
"mmlu:college_biology": {
"acc": 0.2847222222222222,
"acc_stderr": 0.03773809990686935,
"acc_norm": 0.2986111111111111,
"acc_norm_stderr": 0.03827052357950756
},
"mmlu:college_chemistry": {
"acc": 0.29,
"acc_stderr": 0.045604802157206845,
"acc_norm": 0.26,
"acc_norm_stderr": 0.0440844002276808
},
"mmlu:college_computer_science": {
"acc": 0.24,
"acc_stderr": 0.04292346959909282,
"acc_norm": 0.25,
"acc_norm_stderr": 0.04351941398892446
},
"mmlu:college_mathematics": {
"acc": 0.11,
"acc_stderr": 0.03144660377352203,
"acc_norm": 0.23,
"acc_norm_stderr": 0.04229525846816505
},
"mmlu:college_medicine": {
"acc": 0.2254335260115607,
"acc_stderr": 0.03186209851641144,
"acc_norm": 0.2254335260115607,
"acc_norm_stderr": 0.03186209851641143
},
"mmlu:college_physics": {
"acc": 0.12745098039215685,
"acc_stderr": 0.03318224921942076,
"acc_norm": 0.14705882352941177,
"acc_norm_stderr": 0.0352406895156745
},
"mmlu:computer_security": {
"acc": 0.26,
"acc_stderr": 0.044084400227680794,
"acc_norm": 0.28,
"acc_norm_stderr": 0.04512608598542127
},
"mmlu:conceptual_physics": {
"acc": 0.31063829787234043,
"acc_stderr": 0.03025123757921317,
"acc_norm": 0.2170212765957447,
"acc_norm_stderr": 0.026947483121496228
},
"mmlu:econometrics": {
"acc": 0.21929824561403508,
"acc_stderr": 0.03892431106518755,
"acc_norm": 0.19298245614035087,
"acc_norm_stderr": 0.037124548537213684
},
"mmlu:electrical_engineering": {
"acc": 0.2689655172413793,
"acc_stderr": 0.036951833116502325,
"acc_norm": 0.25517241379310346,
"acc_norm_stderr": 0.03632984052707842
},
"mmlu:elementary_mathematics": {
"acc": 0.21693121693121692,
"acc_stderr": 0.02122708244944505,
"acc_norm": 0.2275132275132275,
"acc_norm_stderr": 0.021591269407823774
},
"mmlu:formal_logic": {
"acc": 0.2777777777777778,
"acc_stderr": 0.04006168083848876,
"acc_norm": 0.24603174603174602,
"acc_norm_stderr": 0.038522733649243156
},
"mmlu:global_facts": {
"acc": 0.15,
"acc_stderr": 0.03588702812826371,
"acc_norm": 0.14,
"acc_norm_stderr": 0.03487350880197771
},
"mmlu:high_school_biology": {
"acc": 0.2645161290322581,
"acc_stderr": 0.025091892378859275,
"acc_norm": 0.3096774193548387,
"acc_norm_stderr": 0.026302774983517418
},
"mmlu:high_school_chemistry": {
"acc": 0.18719211822660098,
"acc_stderr": 0.027444924966882618,
"acc_norm": 0.2413793103448276,
"acc_norm_stderr": 0.030108330718011625
},
"mmlu:high_school_computer_science": {
"acc": 0.25,
"acc_stderr": 0.04351941398892446,
"acc_norm": 0.31,
"acc_norm_stderr": 0.046482319871173156
},
"mmlu:high_school_european_history": {
"acc": 0.23030303030303031,
"acc_stderr": 0.03287666758603488,
"acc_norm": 0.3393939393939394,
"acc_norm_stderr": 0.03697442205031596
},
"mmlu:high_school_geography": {
"acc": 0.29797979797979796,
"acc_stderr": 0.032586303838365555,
"acc_norm": 0.30808080808080807,
"acc_norm_stderr": 0.03289477330098615
},
"mmlu:high_school_government_and_politics": {
"acc": 0.25906735751295334,
"acc_stderr": 0.03161877917935411,
"acc_norm": 0.3160621761658031,
"acc_norm_stderr": 0.033553973696861736
},
"mmlu:high_school_macroeconomics": {
"acc": 0.2358974358974359,
"acc_stderr": 0.021525965407408726,
"acc_norm": 0.24358974358974358,
"acc_norm_stderr": 0.021763733684173926
},
"mmlu:high_school_mathematics": {
"acc": 0.14444444444444443,
"acc_stderr": 0.02143376127410489,
"acc_norm": 0.1962962962962963,
"acc_norm_stderr": 0.024217421327417138
},
"mmlu:high_school_microeconomics": {
"acc": 0.24789915966386555,
"acc_stderr": 0.028047967224176896,
"acc_norm": 0.31932773109243695,
"acc_norm_stderr": 0.030283995525884396
},
"mmlu:high_school_physics": {
"acc": 0.23178807947019867,
"acc_stderr": 0.034454062719870546,
"acc_norm": 0.2847682119205298,
"acc_norm_stderr": 0.03684881521389023
},
"mmlu:high_school_psychology": {
"acc": 0.3155963302752294,
# Out:
# The number of tasks that DoReMi outperforms the reference model: 34 = 50.75%
# The number of tasks that DoReMi underperforms the reference model: 29 = 43.28%
# The number of tasks that DoReMi performs the same as the reference model: 4 = 5.97%
# On average, DoReMi outperforms the reference model per task by: 2.07%
# On average, DoReMi underperforms the reference model per task by: 2.13%
# The average accuracy of DoReMi per task: 26.74%
# The average accuracy of the reference model per task: 26.61%

# %%
compute_eval_stats(DOREMI_1B_110K, REFERENCE_1B_200K_UNIFORM)
# Out:
# The number of tasks that DoReMi outperforms the reference model: 48 = 71.64%
# The number of tasks that DoReMi underperforms the reference model: 15 = 22.39%
# The number of tasks that DoReMi performs the same as the reference model: 4 = 5.97%
# On average, DoReMi outperforms the reference model per task by: 3.86%
# On average, DoReMi underperforms the reference model per task by: 3.43%
# The average accuracy of DoReMi per task: 26.74%
# The average accuracy of the reference model per task: 24.74%

# %%
compute_eval_stats(DOREMI_1B_110K, REFERENCE_1B_200K_TOKEN_RATIO)
# Out:
# The number of tasks that DoReMi outperforms the reference model: 28 = 41.79%
# The number of tasks that DoReMi underperforms the reference model: 33 = 49.25%
# The number of tasks that DoReMi performs the same as the reference model: 6 = 8.96%
# On average, DoReMi outperforms the reference model per task by: 1.73%
# On average, DoReMi underperforms the reference model per task by: 1.99%
# The average accuracy of DoReMi per task: 26.74%
# The average accuracy of the reference model per task: 26.99%

# %% [markdown]
# With Average

# %%
AVG_DOREMI_1B_110K = compute_avg_eval(DOREMI_1B_110K)
AVG_REFERENCE_1B_110K_TOKEN_RATIO = compute_avg_eval(REFERENCE_1B_110K_TOKEN_RATIO)

# %%
AVG_REFERENCE_1B_200K_UNIFORM = compute_avg_eval(REFERENCE_1B_200K_UNIFORM)

# %%
compute_eval_stats(AVG_DOREMI_1B_110K, AVG_REFERENCE_1B_110K_TOKEN_RATIO)
# Out:
# The number of tasks that DoReMi outperforms the reference model: 4 = 50.00%
# The number of tasks that DoReMi underperforms the reference model: 4 = 50.00%
# The number of tasks that DoReMi performs the same as the reference model: 0 = 0.00%
# On average, DoReMi outperforms the reference model per task by: 1.47%
# On average, DoReMi underperforms the reference model per task by: 0.61%
# The average accuracy of DoReMi per task: 35.88%
# The average accuracy of the reference model per task: 35.45%

# %%
compute_eval_stats(AVG_DOREMI_1B_110K, AVG_REFERENCE_1B_200K_UNIFORM)
# Out:
# The number of tasks that DoReMi outperforms the reference model: 8 = 100.00%
# The number of tasks that DoReMi underperforms the reference model: 0 = 0.00%
# The number of tasks that DoReMi performs the same as the reference model: 0 = 0.00%
# On average, DoReMi outperforms the reference model per task by: 4.67%
# On average, DoReMi underperforms the reference model per task by: 0.00%
# The average accuracy of DoReMi per task: 35.88%
# The average accuracy of the reference model per task: 31.21%

# %%
# plot_eval(DOREMI_1B_110K, REFERENCE_1B_110K_TOKEN_RATIO)

# %%
plot_eval(AVG_DOREMI_1B_110K, AVG_REFERENCE_1B_110K_TOKEN_RATIO)
# Out:
# <style type="text/css">
# #T_21ead_row0_col0, #T_21ead_row0_col1, #T_21ead_row0_col2, #T_21ead_row0_col3, #T_21ead_row0_col4, #T_21ead_row2_col0, #T_21ead_row2_col1, #T_21ead_row2_col2, #T_21ead_row2_col3, #T_21ead_row2_col4, #T_21ead_row4_col0, #T_21ead_row4_col1, #T_21ead_row4_col2, #T_21ead_row4_col3, #T_21ead_row4_col4, #T_21ead_row7_col0, #T_21ead_row7_col1, #T_21ead_row7_col2, #T_21ead_row7_col3, #T_21ead_row7_col4 {
#   background-color: #59cc0c;
# }
# </style>
# <table id="T_21ead">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21ead_level0_col0" class="col_heading level0 col0" >Task</th>
#       <th id="T_21ead_level0_col1" class="col_heading level0 col1" >DoReMi ACC</th>
#       <th id="T_21ead_level0_col2" class="col_heading level0 col2" >Reference ACC</th>
#       <th id="T_21ead_level0_col3" class="col_heading level0 col3" >DoReMi AccNorm</th>
# ...

# %%
(0.198000+0.444000+0.321000)/3
# Out:
# 0.321

# %%
(0.207000+0.438000+0.322500)/3
# Out:
# 0.3225

# %% [markdown]
# ### 1B at 200k

# %%
DOREMI_1B_200K = {"arc:challenge": {
"acc": 0.193,
"acc_stderr": 0.012486268734370096,
"acc_norm": 0.249,
"acc_norm_stderr": 0.013681600278702293
},
"arc:easy": {
"acc": 0.442,
"acc_stderr": 0.015712507211864204,
"acc_norm": 0.429,
"acc_norm_stderr": 0.015658997547870243
},
"commonsense_qa": {
"acc": 0.274,
"acc_stderr": 0.014111099288259585,
"acc_norm": 0.29,
"acc_norm_stderr": 0.014356395999905697
},
"hellaswag": {
"acc": 0.335,
"acc_stderr": 0.014933117490932573,
"acc_norm": 0.364,
"acc_norm_stderr": 0.015222868840522022
},
"mmlu:abstract_algebra": {
"acc": 0.15,
"acc_stderr": 0.0358870281282637,
"acc_norm": 0.14,
"acc_norm_stderr": 0.03487350880197771
},
"mmlu:anatomy": {
"acc": 0.3333333333333333,
"acc_stderr": 0.04072314811876837,
"acc_norm": 0.28888888888888886,
"acc_norm_stderr": 0.0391545063041425
},
"mmlu:astronomy": {
"acc": 0.24342105263157895,
"acc_stderr": 0.034923496688842384,
"acc_norm": 0.2631578947368421,
"acc_norm_stderr": 0.03583496176361062
},
"mmlu:business_ethics": {
"acc": 0.48,
"acc_stderr": 0.050211673156867795,
"acc_norm": 0.43,
"acc_norm_stderr": 0.04975698519562428
},
"mmlu:clinical_knowledge": {
"acc": 0.22641509433962265,
"acc_stderr": 0.025757559893106748,
"acc_norm": 0.3132075471698113,
"acc_norm_stderr": 0.028544793319055326
},
"mmlu:college_biology": {
"acc": 0.2638888888888889,
"acc_stderr": 0.03685651095897532,
"acc_norm": 0.2569444444444444,
"acc_norm_stderr": 0.03653946969442099
},
"mmlu:college_chemistry": {
"acc": 0.31,
"acc_stderr": 0.04648231987117316,
"acc_norm": 0.27,
"acc_norm_stderr": 0.044619604333847394
},
"mmlu:college_computer_science": {
"acc": 0.21,
"acc_stderr": 0.040936018074033256,
"acc_norm": 0.23,
"acc_norm_stderr": 0.04229525846816505
},
"mmlu:college_mathematics": {
"acc": 0.14,
"acc_stderr": 0.03487350880197771,
"acc_norm": 0.25,
"acc_norm_stderr": 0.04351941398892446
},
"mmlu:college_medicine": {
"acc": 0.26011560693641617,
"acc_stderr": 0.03345036916788991,
"acc_norm": 0.2254335260115607,
"acc_norm_stderr": 0.03186209851641144
},
"mmlu:college_physics": {
"acc": 0.1568627450980392,
"acc_stderr": 0.03618664819936246,
"acc_norm": 0.16666666666666666,
"acc_norm_stderr": 0.03708284662416545
},
"mmlu:computer_security": {
"acc": 0.24,
"acc_stderr": 0.042923469599092816,
"acc_norm": 0.3,
"acc_norm_stderr": 0.046056618647183814
},
"mmlu:conceptual_physics": {
"acc": 0.33191489361702126,
"acc_stderr": 0.03078373675774565,
"acc_norm": 0.25957446808510637,
"acc_norm_stderr": 0.028659179374292326
},
"mmlu:econometrics": {
"acc": 0.21052631578947367,
"acc_stderr": 0.0383515395439942,
"acc_norm": 0.20175438596491227,
"acc_norm_stderr": 0.037752050135836386
},
"mmlu:electrical_engineering": {
"acc": 0.2896551724137931,
"acc_stderr": 0.03780019230438014,
"acc_norm": 0.2620689655172414,
"acc_norm_stderr": 0.036646663372252565
},
"mmlu:elementary_mathematics": {
"acc": 0.21164021164021163,
"acc_stderr": 0.02103733150526289,
"acc_norm": 0.21957671957671956,
"acc_norm_stderr": 0.021320018599770355
},
"mmlu:formal_logic": {
"acc": 0.25396825396825395,
"acc_stderr": 0.03893259610604672,
"acc_norm": 0.21428571428571427,
"acc_norm_stderr": 0.03670066451047182
},
"mmlu:global_facts": {
"acc": 0.2,
"acc_stderr": 0.040201512610368445,
"acc_norm": 0.18,
"acc_norm_stderr": 0.03861229196653696
},
"mmlu:high_school_biology": {
"acc": 0.24838709677419354,
"acc_stderr": 0.024580028921480992,
"acc_norm": 0.3096774193548387,
"acc_norm_stderr": 0.026302774983517418
},
"mmlu:high_school_chemistry": {
"acc": 0.16748768472906403,
"acc_stderr": 0.026273086047535393,
"acc_norm": 0.2315270935960591,
"acc_norm_stderr": 0.029678333141444455
},
"mmlu:high_school_computer_science": {
"acc": 0.25,
"acc_stderr": 0.04351941398892446,
"acc_norm": 0.3,
"acc_norm_stderr": 0.046056618647183814
},
"mmlu:high_school_european_history": {
"acc": 0.24848484848484848,
"acc_stderr": 0.03374402644139406,
"acc_norm": 0.34545454545454546,
"acc_norm_stderr": 0.03713158067481913
},
"mmlu:high_school_geography": {
"acc": 0.30303030303030304,
"acc_stderr": 0.03274287914026867,
"acc_norm": 0.29797979797979796,
"acc_norm_stderr": 0.03258630383836555
},
"mmlu:high_school_government_and_politics": {
"acc": 0.24352331606217617,
"acc_stderr": 0.030975436386845436,
"acc_norm": 0.32124352331606215,
"acc_norm_stderr": 0.033699508685490674
},
"mmlu:high_school_macroeconomics": {
"acc": 0.24615384615384617,
"acc_stderr": 0.02184086699042308,
"acc_norm": 0.2743589743589744,
"acc_norm_stderr": 0.022622765767493228
},
"mmlu:high_school_mathematics": {
"acc": 0.15185185185185185,
"acc_stderr": 0.02188113095738048,
"acc_norm": 0.2,
"acc_norm_stderr": 0.024388430433987654
},
"mmlu:high_school_microeconomics": {
"acc": 0.23529411764705882,
"acc_stderr": 0.027553614467863773,
"acc_norm": 0.33613445378151263,
"acc_norm_stderr": 0.03068473711513537
},
"mmlu:high_school_physics": {
"acc": 0.26490066225165565,
"acc_stderr": 0.03603038545360384,
"acc_norm": 0.304635761589404,
"acc_norm_stderr": 0.03757949922943343
},
"mmlu:high_school_psychology": {
"acc": 0.29174311926605506,
"acc_stderr": 0.019489300968876546,
"acc_norm": 0.29357798165137616,
"acc_norm_stderr": 0.019525151122639667
},
"mmlu:high_school_statistics": {
"acc": 0.27314814814814814,
"acc_stderr": 0.030388051301678116,
"acc_norm": 0.2916666666666667,
"acc_norm_stderr": 0.03099866630456053
},
"mmlu:high_school_us_history": {
"acc": 0.22549019607843138,
"acc_stderr": 0.02933116229425172,
"acc_norm": 0.31862745098039214,
"acc_norm_stderr": 0.032702871814820796
},
"mmlu:high_school_world_history": {
"acc": 0.21940928270042195,
"acc_stderr": 0.026939106581553945,
"acc_norm": 0.2616033755274262,
"acc_norm_stderr": 0.028609516716994934
},
"mmlu:human_aging": {
"acc": 0.33183856502242154,
"acc_stderr": 0.03160295143776679,
"acc_norm": 0.27802690582959644,
"acc_norm_stderr": 0.03006958487449403
},
"mmlu:human_sexuality": {
"acc": 0.35877862595419846,
"acc_stderr": 0.04206739313864908,
"acc_norm": 0.32061068702290074,
"acc_norm_stderr": 0.04093329229834278
},
"mmlu:international_law": {
"acc": 0.15702479338842976,
"acc_stderr": 0.0332124484254713,
"acc_norm": 0.23140495867768596,
"acc_norm_stderr": 0.038498560987940904
},
"mmlu:jurisprudence": {
"acc": 0.18518518518518517,
"acc_stderr": 0.03755265865037181,
"acc_norm": 0.25925925925925924,
"acc_norm_stderr": 0.04236511258094633
},
"mmlu:logical_fallacies": {
"acc": 0.25766871165644173,
"acc_stderr": 0.03436150827846917,
"acc_norm": 0.31901840490797545,
"acc_norm_stderr": 0.03661997551073836
},
"mmlu:machine_learning": {
"acc": 0.25892857142857145,
"acc_stderr": 0.041577515398656284,
"acc_norm": 0.26785714285714285,
"acc_norm_stderr": 0.04203277291467762
},
"mmlu:management": {
"acc": 0.2524271844660194,
"acc_stderr": 0.04301250399690879,
"acc_norm": 0.34951456310679613,
"acc_norm_stderr": 0.04721188506097172
},
"mmlu:marketing": {
"acc": 0.33760683760683763,
"acc_stderr": 0.03098029699261855,
"acc_norm": 0.3888888888888889,
"acc_norm_stderr": 0.031937057262002924
},
"mmlu:medical_genetics": {
"acc": 0.27,
"acc_stderr": 0.044619604333847394,
"acc_norm": 0.31,
"acc_norm_stderr": 0.04648231987117316
},
"mmlu:miscellaneous": {
"acc": 0.33077905491698595,
"acc_stderr": 0.01682481846256374,
"acc_norm": 0.32567049808429116,
"acc_norm_stderr": 0.016757989458549675
},
"mmlu:moral_disputes": {
"acc": 0.20520231213872833,
"acc_stderr": 0.021742519835276287,
"acc_norm": 0.2138728323699422,
"acc_norm_stderr": 0.022075709251757177
},
"mmlu:moral_scenarios": {
"acc": 0.23798882681564246,
"acc_stderr": 0.014242630070574915,
"acc_norm": 0.27262569832402234,
"acc_norm_stderr": 0.014893391735249588
},
"mmlu:nutrition": {
"acc": 0.22875816993464052,
"acc_stderr": 0.024051029739912248,
"acc_norm": 0.28431372549019607,
"acc_norm_stderr": 0.02582916327275748
},
"mmlu:philosophy": {
"acc": 0.22508038585209003,
"acc_stderr": 0.023720088516179027,
"acc_norm": 0.2797427652733119,
"acc_norm_stderr": 0.025494259350694902
},
"mmlu:prehistory": {
"acc": 0.2716049382716049,
"acc_stderr": 0.02474862449053738,
"acc_norm": 0.20987654320987653,
"acc_norm_stderr": 0.022658344085981375
},
"mmlu:professional_accounting": {
"acc": 0.2624113475177305,
"acc_stderr": 0.026244920349843,
"acc_norm": 0.23049645390070922,
"acc_norm_stderr": 0.025123739226872416
},
"mmlu:professional_law": {
"acc": 0.251,
"acc_stderr": 0.01371813351688892,
"acc_norm": 0.271,
"acc_norm_stderr": 0.014062601350986186
},
"mmlu:professional_medicine": {
"acc": 0.23161764705882354,
"acc_stderr": 0.025626533803777565,
"acc_norm": 0.27941176470588236,
"acc_norm_stderr": 0.027257202606114948
},
"mmlu:professional_psychology": {
"acc": 0.2679738562091503,
"acc_stderr": 0.017917974069594726,
"acc_norm": 0.24509803921568626,
"acc_norm_stderr": 0.017401816711427657
},
"mmlu:public_relations": {
"acc": 0.35454545454545455,
"acc_stderr": 0.04582004841505417,
"acc_norm": 0.19090909090909092,
"acc_norm_stderr": 0.03764425585984924
},

"mmlu:security_studies": {
"acc": 0.31020408163265306,
"acc_stderr": 0.029613459872484378,
"acc_norm": 0.22448979591836735,
"acc_norm_stderr": 0.02671143055553842
},
"mmlu:sociology": {
"acc": 0.22388059701492538,
"acc_stderr": 0.029475250236017197,
"acc_norm": 0.23383084577114427,
"acc_norm_stderr": 0.029929415408348387
},
"mmlu:us_foreign_policy": {
"acc": 0.27,
"acc_stderr": 0.044619604333847394,
"acc_norm": 0.21,
"acc_norm_stderr": 0.04093601807403326
},
"mmlu:virology": {
"acc": 0.22289156626506024,
"acc_stderr": 0.032400048255946876,
"acc_norm": 0.2710843373493976,
"acc_norm_stderr": 0.03460579907553027
},
"mmlu:world_religions": {
"acc": 0.2046783625730994,
"acc_stderr": 0.030944459778533214,
"acc_norm": 0.2807017543859649,
"acc_norm_stderr": 0.034462962170884265
},
"openbookqa": {
"acc": 0.168,
"acc_stderr": 0.01673655354154191,
"acc_norm": 0.3,
"acc_norm_stderr": 0.020514426225628046
},
"piqa": {
"acc": 0.648,
"acc_stderr": 0.015110404505648658,
"acc_norm": 0.682,
"acc_norm_stderr": 0.0147340793093119
},
"siqa": {
"acc": 0.365,
"acc_stderr": 0.015231776226264902,
"acc_norm": 0.399,
"acc_norm_stderr": 0.01549319331316291
},
"winogrande": {
"acc": 0.523,
"acc_stderr": 0.015802554246726098,
"acc_norm": 0.503,
"acc_norm_stderr": 0.015819015179246724
},
"arc:_average": {
"acc": 0.3175,
"acc_stderr": 0.01409938797311715,
"acc_norm": 0.33899999999999997,
"acc_norm_stderr": 0.014670298913286268
},
"mmlu:_average": {
"acc": 0.25243370381209446,
"acc_stderr": 0.032145687260140735,
"acc_norm": 0.268521951246721,
"acc_norm_stderr": 0.03288407634470946
}
}

# %%
# compute_eval_stats(DOREMI_1B_200K, REFERENCE_1B_110K_TOKEN_RATIO)

# %%
# compute_eval_stats(DOREMI_1B_200K, DOREMI_1B_110K)

# %%
# compute_eval_stats(REFERENCE_1B_200K_TOKEN_RATIO, REFERENCE_1B_110K_TOKEN_RATIO)

# %%
# compute_eval_stats(DOREMI_1B_200K, REFERENCE_1B_200K_TOKEN_RATIO)

# %% [markdown]
# With average

# %%
AVG_DOREMI_1B_200K = compute_avg_eval(DOREMI_1B_200K)
AVG_REFERENCE_1B_200K_TOKEN_RATIO = compute_avg_eval(REFERENCE_1B_200K_TOKEN_RATIO)

# %%
compute_eval_stats(AVG_DOREMI_1B_200K, AVG_REFERENCE_1B_200K_TOKEN_RATIO)
# Out:
# The number of tasks that DoReMi outperforms the reference model: 5 = 62.50%
# The number of tasks that DoReMi underperforms the reference model: 3 = 37.50%
# The number of tasks that DoReMi performs the same as the reference model: 0 = 0.00%
# On average, DoReMi outperforms the reference model per task by: 0.84%
# On average, DoReMi underperforms the reference model per task by: 0.85%
# The average accuracy of DoReMi per task: 36.04%
# The average accuracy of the reference model per task: 35.83%

# %%
plot_eval(AVG_DOREMI_1B_200K, AVG_REFERENCE_1B_200K_TOKEN_RATIO)
# Out:
# <style type="text/css">
# #T_2fd9f_row2_col0, #T_2fd9f_row2_col1, #T_2fd9f_row2_col2, #T_2fd9f_row2_col3, #T_2fd9f_row2_col4, #T_2fd9f_row3_col0, #T_2fd9f_row3_col1, #T_2fd9f_row3_col2, #T_2fd9f_row3_col3, #T_2fd9f_row3_col4, #T_2fd9f_row4_col0, #T_2fd9f_row4_col1, #T_2fd9f_row4_col2, #T_2fd9f_row4_col3, #T_2fd9f_row4_col4, #T_2fd9f_row5_col0, #T_2fd9f_row5_col1, #T_2fd9f_row5_col2, #T_2fd9f_row5_col3, #T_2fd9f_row5_col4, #T_2fd9f_row7_col0, #T_2fd9f_row7_col1, #T_2fd9f_row7_col2, #T_2fd9f_row7_col3, #T_2fd9f_row7_col4 {
#   background-color: #59cc0c;
# }
# </style>
# <table id="T_2fd9f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2fd9f_level0_col0" class="col_heading level0 col0" >Task</th>
#       <th id="T_2fd9f_level0_col1" class="col_heading level0 col1" >DoReMi ACC</th>
#       <th id="T_2fd9f_level0_col2" class="col_heading level0 col2" >Reference ACC</th>
# ...
