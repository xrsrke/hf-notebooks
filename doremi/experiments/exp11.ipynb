# %% [markdown]
# ### DoReMi Weights at 175k checkpoint

# %%
import sys
sys.path.append("/Users/huggingface/DATA/notebooks/hf-notebooks/doremi/experiments/")
from utils import plot_domain_weights, print_name_weights, get_mamba_dataset_weights, plot_domain_weights_comparison

# %%
import torch

# %%
weights_175k = torch.tensor([0.6753, 0.1010, 0.1046, 0.0068, 0.0343, 0.0220, 0.0023, 0.0075, 0.0050,
        0.0030, 0.0036, 0.0102, 0.0051, 0.0017, 0.0032, 0.0144])

# %%
print_name_weights(weights=weights_175k)
# Out:
# fineweb tensor(0.6753)
# stack_full tensor(0.1010)
# c4 tensor(0.1046)
# arxiv tensor(0.0068)
# synthetic-data tensor(0.0343)
# stack-pull-requests tensor(0.0220)
# stack-jupyter-scripts tensor(0.0023)
# stack-jupyter-structured tensor(0.0075)
# open-web-math tensor(0.0050)
# stack-issues tensor(0.0030)
# stackoverflow tensor(0.0036)
# wikipedia tensor(0.0102)
# project-gutenberg tensor(0.0051)
# deepmind-math tensor(0.0017)
# stack-kaggle-scripts tensor(0.0032)
# stack-documentation tensor(0.0144)
# ----- sorthing bellow ---
# fineweb tensor(0.6753) tensor(0)
# c4 tensor(0.1046) tensor(2)
# stack_full tensor(0.1010) tensor(1)
# synthetic-data tensor(0.0343) tensor(4)
# stack-pull-requests tensor(0.0220) tensor(5)
# stack-documentation tensor(0.0144) tensor(15)
# wikipedia tensor(0.0102) tensor(11)
# stack-jupyter-structured tensor(0.0075) tensor(7)
# arxiv tensor(0.0068) tensor(3)
# project-gutenberg tensor(0.0051) tensor(12)
# open-web-math tensor(0.0050) tensor(8)
# ...

# %%
plot_domain_weights(weights=weights_175k)

# %%
get_mamba_dataset_weights()
# Out:
# [0.6528185542877774,
#  0.16263511250672186,
#  0.09467099334990459,
#  0.0164414763120786,
#  0.01550254043723999,
#  0.011027415115022095,
#  0.009185813766226018,
#  0.00829319356314609,
#  0.0075958052296511815,
#  0.006169673529954469,
#  0.005622163270287513,
#  0.0028959040831890684,
#  0.0026854210021118007,
#  0.00262224207925128,
#  0.0009357517775398223,
#  0.0008979396898982224]

# %%
plot_domain_weights_comparison(doremi_weights=weights_175k, reference_weights=torch.tensor(get_mamba_dataset_weights()))

# %% [markdown]
# ### DoReMi weights at 200k

# %%
weights_200k = torch.tensor([0.6852, 0.0974, 0.1035, 0.0067, 0.0323, 0.0200, 0.0023, 0.0073, 0.0051,
        0.0030, 0.0036, 0.0100, 0.0052, 0.0016, 0.0030, 0.0138])

# %%
(weights_200k - weights_175k).abs().max()
# Out:
# tensor(0.0099)

# %%
print_name_weights(weights=weights_200k)
# Out:
# fineweb tensor(0.6852)
# stack_full tensor(0.0974)
# c4 tensor(0.1035)
# arxiv tensor(0.0067)
# synthetic-data tensor(0.0323)
# stack-pull-requests tensor(0.0200)
# stack-jupyter-scripts tensor(0.0023)
# stack-jupyter-structured tensor(0.0073)
# open-web-math tensor(0.0051)
# stack-issues tensor(0.0030)
# stackoverflow tensor(0.0036)
# wikipedia tensor(0.0100)
# project-gutenberg tensor(0.0052)
# deepmind-math tensor(0.0016)
# stack-kaggle-scripts tensor(0.0030)
# stack-documentation tensor(0.0138)
# ----- sorthing bellow ---
# fineweb tensor(0.6852) tensor(0)
# c4 tensor(0.1035) tensor(2)
# stack_full tensor(0.0974) tensor(1)
# synthetic-data tensor(0.0323) tensor(4)
# stack-pull-requests tensor(0.0200) tensor(5)
# stack-documentation tensor(0.0138) tensor(15)
# wikipedia tensor(0.0100) tensor(11)
# stack-jupyter-structured tensor(0.0073) tensor(7)
# arxiv tensor(0.0067) tensor(3)
# project-gutenberg tensor(0.0052) tensor(12)
# open-web-math tensor(0.0051) tensor(8)
# ...
