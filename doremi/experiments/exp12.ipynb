# %%
import sys
sys.path.append("/Users/huggingface/DATA/notebooks/hf-notebooks/doremi/experiments/")
from utils import plot_domain_weights, print_name_weights, get_mamba_dataset_weights, plot_domain_weights_comparison

# %%
import torch

# %%
weights_200k = torch.tensor([0.6900, 0.0676, 0.1017, 0.0038, 0.0479, 0.0220, 0.0020, 0.0050, 0.0035,
        0.0026, 0.0027, 0.0179, 0.0072, 0.0014, 0.0031, 0.0216])

# %%
(weights_200k - exp11_weights_200k).abs().max()
# Out:
# tensor(0.0298)

# %%
print_name_weights(weights=weights_200k)
# Out:
# fineweb tensor(0.6900)
# stack_full tensor(0.0676)
# c4 tensor(0.1017)
# arxiv tensor(0.0038)
# synthetic-data tensor(0.0479)
# stack-pull-requests tensor(0.0220)
# stack-jupyter-scripts tensor(0.0020)
# stack-jupyter-structured tensor(0.0050)
# open-web-math tensor(0.0035)
# stack-issues tensor(0.0026)
# stackoverflow tensor(0.0027)
# wikipedia tensor(0.0179)
# project-gutenberg tensor(0.0072)
# deepmind-math tensor(0.0014)
# stack-kaggle-scripts tensor(0.0031)
# stack-documentation tensor(0.0216)
# ----- sorthing bellow ---
# fineweb tensor(0.6900) tensor(0)
# c4 tensor(0.1017) tensor(2)
# stack_full tensor(0.0676) tensor(1)
# synthetic-data tensor(0.0479) tensor(4)
# stack-pull-requests tensor(0.0220) tensor(5)
# stack-documentation tensor(0.0216) tensor(15)
# wikipedia tensor(0.0179) tensor(11)
# project-gutenberg tensor(0.0072) tensor(12)
# stack-jupyter-structured tensor(0.0050) tensor(7)
# arxiv tensor(0.0038) tensor(3)
# open-web-math tensor(0.0035) tensor(8)
# ...

# %%
plot_domain_weights(weights=weights_200k)
